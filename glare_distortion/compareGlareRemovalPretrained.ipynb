# %%
import torch
from torchvision.models import resnet50, ResNet50_Weights
import cv2
from torchvision.transforms import transforms
from PIL import Image
import os
import re

# %%
weights = ResNet50_Weights.IMAGENET1K_V1
model = resnet50(weights=weights)

preprocess = weights.transforms()
categories = weights.meta["categories"]

def image_loader(image_name):
    if not os.path.exists(image_name):
        print(f"ERROR: File not found at path: {image_name}")
        return None
        
    image = Image.open(image_name).convert("RGB")
    return image

# %%
glare_images = 'glare_images/'
glare_reduction = 'glare-removal-dnn-pretrained/test_result'
results = {}
labels = []

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
def getLabel(filename):
    match = re.search(r'glare\d+(.*?)\.jpg$', filename)
    if match:
        return match.group(1) 
    return None

# %%
def get_predictions(input_batch, image_type, file_key, verbose=False):
    with torch.no_grad():
        output = model(input_batch)
        
    probabilities = torch.nn.functional.softmax(output[0], dim=0)
    
    # Get Top 5 Predictions
    top5_prob, top5_indices = torch.topk(probabilities, 5)
    
    predictions = []
    for i in range(top5_prob.size(0)):
        predicted_index = top5_indices[i].item()
        predicted_label = categories[predicted_index]
        probability = top5_prob[i].item()
        predictions.append({
            "rank": i + 1,
            "label": predicted_label,
            "probability": probability
        })
    
    best_pred = predictions[0]
    
    results[file_key][image_type] = {
        "best_label": best_pred["label"],
        "best_probability": best_pred["probability"],
        "top_5_predictions": predictions
    }
    
    if(verbose):
        print(f"  {image_type.capitalize()} Best Label: **{best_pred['label']}** (P: {best_pred['probability']:.4f})")

# %%
verbose = False
print(f"Starting batch prediction on device: {device}")
print("-" * 50)

for filename in os.listdir(glare_images):
    if filename.endswith(".jpg") or filename.endswith(".jpeg") or filename.endswith(".png"):
        
        original_file_path = os.path.join(glare_images, filename)
        processed_filename = 'processed_' + filename
        processed_file_path = os.path.join(glare_reduction, processed_filename) 
        
        if not os.path.exists(processed_file_path):
            print(f"Processed file not found for **{filename}**. Skipping.")
            continue
            
        if(verbose):
            print(f"Processing: **{processed_filename}**")
        
        file_key = os.path.splitext(filename)[0]
        results[file_key] = {
            "original": {},
            "processed": {},
            "label" : getLabel(filename)
        }
        
        try:
            image_original = image_loader(original_file_path)
            image_processed = image_loader(processed_file_path)
            
            input_tensor_original = preprocess(image_original)
            input_tensor_processed = preprocess(image_processed)
            
            input_batch_original = input_tensor_original.unsqueeze(0).to(device)
            input_batch_processed = input_tensor_processed.unsqueeze(0).to(device)
            
            get_predictions(input_batch_original, "original", file_key)
            get_predictions(input_batch_processed, "processed",file_key)
            if(verbose):
                print("-" * 50)
            
        except Exception as e:
            print(f"An error occurred while processing **{filename}**: {e}")
            del results[file_key] # Remove incomplete result
            print("-" * 50)
            continue
            
print("Batch processing complete.")
# Out:
# Starting batch prediction on device: cuda
# --------------------------------------------------
# Batch processing complete.

# %%
def check_label_match(ground_truth, predicted_label):
    gt = ground_truth.lower().replace(" ", "")
    pl = predicted_label.lower().replace(" ", "")
    # print(f"ground truth: {gt} == {pl} : predicted")
    if gt in pl:
        return True
    
    if pl in gt:
        return True
        
    if gt == pl:
        return True
        
    return False

# %%
def print_side_by_side_comparison(results_dict, print_results=False):
    max_label_width = 0
    
    # Find the longest label across all Top 5 lists
    for data in results_dict.values():
        for pred in data["original"]["top_5_predictions"]:
            max_label_width = max(max_label_width, len(pred["label"]))
        for pred in data["processed"]["top_5_predictions"]:
            max_label_width = max(max_label_width, len(pred["label"]))

    label_padding = max_label_width + 12
    original_correct = 0
    processed_correct = 0
    processed_improved_list = []
    for file_key, data in results_dict.items():
        original_preds = data["original"]["top_5_predictions"]
        processed_preds = data["processed"]["top_5_predictions"]
        ground_truth = data['label'] 
        if(print_results):
            print("=" * 70)
            print(f"**{file_key}** (Ground Truth: {ground_truth})")
            print("-" * 70)
            
            header_format = f"{'Original Top 5':<{label_padding}} | {'Processed Top 5'}"
            print(header_format)
            print("-" * 70)

        original_is_counted = False
        processed_is_counted = False
        original_prob = 0
        processed_prob = 0
        for i in range(5):
            orig_label = original_preds[i]['label']
            orig_prob = original_preds[i]['probability']
            orig_is_match = check_label_match(ground_truth, orig_label)
            orig_star = "*" if orig_is_match else ""
            if orig_is_match and not original_is_counted:
                original_correct += 1 
                original_is_counted = True
                original_prob = orig_prob
            
            proc_label = processed_preds[i]['label']
            proc_prob = processed_preds[i]['probability']
            proc_is_match = check_label_match(ground_truth, proc_label)
            proc_star = "*" if proc_is_match else ""
            if proc_is_match and not processed_is_counted:
                processed_correct += 1 
                processed_is_counted = True
                processed_prob = proc_prob
            
            orig_output = f"{orig_label}: {orig_prob:.4f}{orig_star}"
            proc_output = f"{proc_label}: {proc_prob:.4f}{proc_star}"
            
            # Use f-string formatting to align the original column based on max width
            comparison_line = f"{orig_output:<{label_padding}} | {proc_output}"
            
            if(print_results):
                print(comparison_line)

        if(original_correct != 0 and processed_correct != 0 and original_prob < processed_prob): 
            processed_improved_list.append({file_key, original_prob, processed_prob})
    if(print_results):
        print("=" * 70)
    return original_correct, processed_correct, processed_improved_list

# %%
print_results = True
original_correct, predicted_correct, processed_improved_list = print_side_by_side_comparison(results, print_results=print_results)
# Out:
# ======================================================================
# **glare10spotlight** (Ground Truth: spotlight)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# spotlight: 0.4768*              | mouse: 0.3738
# lampshade: 0.4680               | CD player: 0.2140
# table lamp: 0.0290              | bubble: 0.0833
# candle: 0.0129                  | cassette: 0.0342
# matchstick: 0.0014              | tape player: 0.0276
# ======================================================================
# **glare11bowl** (Ground Truth: bowl)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# spotlight: 0.5431               | candle: 0.1439
# candle: 0.1663                  | nipple: 0.0969
# mouse: 0.0619                   | pill bottle: 0.0815
# bubble: 0.0505                  | spotlight: 0.0769
# Petri dish: 0.0440              | mouse: 0.0663
# ======================================================================
# **glare12ruler** (Ground Truth: ruler)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# rule: 0.1706*                   | radio: 0.3083
# digital clock: 0.1405           | modem: 0.1832
# CD player: 0.1028               | digital clock: 0.1184
# microwave: 0.0990               | CD player: 0.1159
# screen: 0.0802                  | screen: 0.0364
# ======================================================================
# **glare13notebook** (Ground Truth: notebook)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# monitor: 0.3529                 | screen: 0.4148
# screen: 0.3053                  | monitor: 0.2449
# television: 0.1011              | modem: 0.0775
# notebook: 0.0450*               | laptop: 0.0562
# projector: 0.0288               | television: 0.0379
# ======================================================================
# **glare14remotecontroller** (Ground Truth: remotecontroller)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# remote control: 0.7515*         | cellular telephone: 0.2003
# cellular telephone: 0.1530      | remote control: 0.1644*
# CD player: 0.0144               | hard disc: 0.0812
# modem: 0.0136                   | CD player: 0.0766
# projector: 0.0127               | projector: 0.0607
# ======================================================================
# **glare15screwdriver** (Ground Truth: screwdriver)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# screwdriver: 0.9996*            | screwdriver: 0.9933*
# plunger: 0.0003                 | syringe: 0.0031
# syringe: 0.0001                 | letter opener: 0.0012
# swab: 0.0000                    | whistle: 0.0003
# paddle: 0.0000                  | plunger: 0.0002
# ======================================================================
# **glare16RV** (Ground Truth: RV)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# ambulance: 0.2485               | airliner: 0.1697
# moving van: 0.1827              | wing: 0.1405
# police van: 0.1110              | ambulance: 0.1381
# carton: 0.1093                  | carton: 0.0413
# minibus: 0.0836                 | police van: 0.0360
# ======================================================================
# **glare17bandaid** (Ground Truth: bandaid)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# Band Aid: 0.9999*               | Band Aid: 0.6373*
# spatula: 0.0000                 | rubber eraser: 0.0900
# rubber eraser: 0.0000           | paintbrush: 0.0315
# seat belt: 0.0000               | pencil sharpener: 0.0300
# envelope: 0.0000                | spatula: 0.0143
# ======================================================================
# **glare18remotecontrol** (Ground Truth: remotecontrol)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# remote control: 0.9581*         | remote control: 0.9752*
# joystick: 0.0054                | cellular telephone: 0.0035
# cellular telephone: 0.0053      | torch: 0.0026
# switch: 0.0026                  | hand-held computer: 0.0022
# radio: 0.0022                   | joystick: 0.0015
# ======================================================================
# **glare19ballpoint** (Ground Truth: ballpoint)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# ballpoint: 0.6869*              | ballpoint: 0.7803*
# rubber eraser: 0.0848           | damselfly: 0.0544
# pencil sharpener: 0.0329        | rubber eraser: 0.0331
# hammer: 0.0262                  | pencil sharpener: 0.0125
# paintbrush: 0.0187              | fountain pen: 0.0124
# ======================================================================
# **glare1sunglasses** (Ground Truth: sunglasses)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# sunglasses: 0.7765*             | sunglasses: 0.4496*
# sunglass: 0.2158*               | sunglass: 0.3485*
# projector: 0.0039               | binoculars: 0.0089
# binoculars: 0.0012              | projector: 0.0068
# washer: 0.0003                  | car mirror: 0.0062
# ======================================================================
# **glare20window** (Ground Truth: window)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# sliding door: 0.4832            | window screen: 0.4590*
# window screen: 0.4329*          | sliding door: 0.2787
# window shade: 0.0696*           | window shade: 0.0868*
# fire screen: 0.0044             | fire screen: 0.0769
# shoji: 0.0018                   | microwave: 0.0163
# ======================================================================
# **glare21ZOMG** (Ground Truth: ZOMG)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# tennis ball: 0.9146             | tennis ball: 0.2763
# volleyball: 0.0290              | pencil box: 0.1251
# soccer ball: 0.0238             | diaper: 0.1086
# CD player: 0.0041               | Band Aid: 0.0436
# rugby ball: 0.0040              | bib: 0.0290
# ======================================================================
# **glare22waterbottle** (Ground Truth: waterbottle)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# water bottle: 0.9011*           | water bottle: 0.8009*
# pop bottle: 0.0894              | pop bottle: 0.0400
# beer bottle: 0.0045             | nipple: 0.0125
# beer glass: 0.0009              | snorkel: 0.0110
# wine bottle: 0.0006             | syringe: 0.0085
# ======================================================================
# **glare23microwave** (Ground Truth: microwave)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# microwave: 0.5417*              | television: 0.0815
# rotisserie: 0.0821              | loudspeaker: 0.0561
# window screen: 0.0648           | cassette player: 0.0444
# toaster: 0.0536                 | radio: 0.0344
# fire screen: 0.0363             | screen: 0.0324
# ======================================================================
# **glare24cabinet** (Ground Truth: cabinet)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# stove: 0.3099                   | stove: 0.6090
# microwave: 0.1454               | microwave: 0.2879
# safe: 0.1446                    | plate rack: 0.0170
# refrigerator: 0.0584            | television: 0.0103
# switch: 0.0477                  | rotisserie: 0.0063
# ======================================================================
# **glare25rubber** (Ground Truth: rubber)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# rubber eraser: 0.8904*          | odometer: 0.1002
# packet: 0.0335                  | packet: 0.0657
# matchstick: 0.0316              | rubber eraser: 0.0430*
# book jacket: 0.0115             | parking meter: 0.0386
# street sign: 0.0059             | cash machine: 0.0332
# ======================================================================
# **glare26winebottle** (Ground Truth: winebottle)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# wine bottle: 0.3121*            | whiskey jug: 0.3372
# beer bottle: 0.2927             | beer bottle: 0.1209
# whiskey jug: 0.2500             | wine bottle: 0.0863*
# pop bottle: 0.0586              | pop bottle: 0.0861
# red wine: 0.0521                | cocktail shaker: 0.0388
# ======================================================================
# **glare27coffeemug** (Ground Truth: coffeemug)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# coffee mug: 0.8901*             | coffee mug: 0.6632*
# cup: 0.0835                     | beer glass: 0.1225
# espresso: 0.0068                | cup: 0.0917
# beer glass: 0.0061              | water jug: 0.0297
# coffeepot: 0.0030               | espresso: 0.0150
# ======================================================================
# **glare28mixingbowl** (Ground Truth: mixingbowl)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# mixing bowl: 0.4658*            | isopod: 0.2388
# ladle: 0.0403                   | ladle: 0.1054
# measuring cup: 0.0364           | goblet: 0.0999
# Petri dish: 0.0339              | beaker: 0.0684
# tray: 0.0333                    | beer glass: 0.0599
# ======================================================================
# **glare29toaster** (Ground Truth: toaster)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# toaster: 0.7179*                | coffeepot: 0.0661
# car mirror: 0.0577              | car mirror: 0.0503
# minivan: 0.0136                 | crash helmet: 0.0475
# coffeepot: 0.0134               | can opener: 0.0440
# revolver: 0.0113                | loudspeaker: 0.0374
# ======================================================================
# **glare2backpack** (Ground Truth: backpack)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# balloon: 0.1660                 | caldron: 0.0872
# parachute: 0.1308               | scuba diver: 0.0691
# spotlight: 0.0830               | stage: 0.0406
# bobsled: 0.0468                 | bubble: 0.0390
# bubble: 0.0467                  | laptop: 0.0359
# ======================================================================
# **glare2Car** (Ground Truth: Car)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# fire engine: 0.0890             | goldfish: 0.1022
# spotlight: 0.0760               | electric ray: 0.0811
# volcano: 0.0561                 | rock beauty: 0.0529
# snowplow: 0.0493                | caldron: 0.0493
# fountain: 0.0349                | axolotl: 0.0403
# ======================================================================
# **glare30watertank** (Ground Truth: watertank)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# beer glass: 0.1181              | caldron: 0.0916
# spotlight: 0.0967               | beaker: 0.0719
# goblet: 0.0703                  | water jug: 0.0666
# bucket: 0.0650                  | milk can: 0.0544
# water jug: 0.0497               | coffeepot: 0.0437
# ======================================================================
# **glare31television** (Ground Truth: television)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# grand piano: 0.1995             | grand piano: 0.0840
# washbasin: 0.1242               | washbasin: 0.0351
# home theater: 0.0717            | microwave: 0.0289
# projector: 0.0516               | upright: 0.0237
# loudspeaker: 0.0410             | goblet: 0.0216
# ======================================================================
# **glare32refrigerator** (Ground Truth: refrigerator)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# sliding door: 0.1869            | window shade: 0.1453
# window shade: 0.1273            | sliding door: 0.0991
# bannister: 0.0595               | dishwasher: 0.0679
# dishwasher: 0.0532              | shower curtain: 0.0675
# spotlight: 0.0313               | toaster: 0.0485
# ======================================================================
# **glare33sandal** (Ground Truth: sandal)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# Band Aid: 0.6448                | knee pad: 0.1952
# punching bag: 0.0622            | punching bag: 0.1252
# water bottle: 0.0340            | shower curtain: 0.1245
# nipple: 0.0284                  | Band Aid: 0.0940
# pill bottle: 0.0282             | water jug: 0.0589
# ======================================================================
# **glare34broom** (Ground Truth: broom)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# broom: 0.9994*                  | broom: 0.4990*
# swab: 0.0002                    | shovel: 0.1616
# paintbrush: 0.0001              | wooden spoon: 0.1219
# shovel: 0.0001                  | spatula: 0.0702
# plunger: 0.0001                 | ladle: 0.0297
# ======================================================================
# **glare35washer** (Ground Truth: washer)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# washer: 0.8998*                 | washer: 0.6340*
# microwave: 0.0490               | microwave: 0.1181
# scale: 0.0224                   | scale: 0.0990
# CD player: 0.0095               | CD player: 0.0657
# photocopier: 0.0069             | tape player: 0.0255
# ======================================================================
# **glare36strainer** (Ground Truth: strainer)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# strainer: 0.9993*               | strainer: 0.9942*
# saltshaker: 0.0005              | saltshaker: 0.0045
# ladle: 0.0001                   | cocktail shaker: 0.0004
# cocktail shaker: 0.0001         | ladle: 0.0003
# coffeepot: 0.0000               | coffeepot: 0.0001
# ======================================================================
# **glare37bakingpan** (Ground Truth: bakingpan)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# projector: 0.5669               | slot: 0.1835
# spotlight: 0.0911               | cab: 0.1206
# stove: 0.0373                   | CD player: 0.1036
# laptop: 0.0297                  | racer: 0.0771
# rotisserie: 0.0189              | digital clock: 0.0548
# ======================================================================
# **glare38measuringcup** (Ground Truth: measuringcup)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# measuring cup: 0.9862*          | measuring cup: 0.9908*
# cocktail shaker: 0.0092         | cocktail shaker: 0.0062
# cup: 0.0012*                    | beaker: 0.0019
# beer glass: 0.0010              | water jug: 0.0002
# water jug: 0.0004               | beer glass: 0.0001
# ======================================================================
# **glare39canopener** (Ground Truth: canopener)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# fountain pen: 0.1581            | pencil box: 0.3098
# ballpoint: 0.1188               | hair slide: 0.0600
# hair slide: 0.0911              | ballpoint: 0.0582
# scabbard: 0.0880                | Band Aid: 0.0518
# projector: 0.0564               | fountain pen: 0.0464
# ======================================================================
# **glare3lampshade** (Ground Truth: lampshade)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# lampshade: 0.2596*              | water bottle: 0.4472
# goblet: 0.1696                  | bubble: 0.1380
# radio telescope: 0.0980         | perfume: 0.0953
# cup: 0.0654                     | goblet: 0.0912
# table lamp: 0.0490              | pinwheel: 0.0206
# ======================================================================
# **glare40laptop** (Ground Truth: laptop)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# laptop: 0.7206*                 | laptop: 0.7657*
# notebook: 0.2509                | notebook: 0.1087
# computer keyboard: 0.0128       | desktop computer: 0.0243
# monitor: 0.0029                 | modem: 0.0110
# space bar: 0.0028               | computer keyboard: 0.0100
# ======================================================================
# **glare41switch** (Ground Truth: switch)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# switch: 0.9995*                 | switch: 0.9966*
# safe: 0.0001                    | medicine chest: 0.0005
# medicine chest: 0.0000          | safe: 0.0003
# wall clock: 0.0000              | wall clock: 0.0003
# spotlight: 0.0000               | combination lock: 0.0002
# ======================================================================
# **glare42umbrella** (Ground Truth: umbrella)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# umbrella: 0.9968*               | umbrella: 0.9553*
# plastic bag: 0.0017             | plastic bag: 0.0269
# mountain tent: 0.0006           | mountain tent: 0.0029
# mosquito net: 0.0002            | mosquito net: 0.0028
# lampshade: 0.0001               | projector: 0.0007
# ======================================================================
# **glare43welcomemat** (Ground Truth: welcomemat)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# screen: 0.3417                  | cash machine: 0.1139
# monitor: 0.2341                 | screen: 0.0965
# modem: 0.0385                   | projector: 0.0682
# laptop: 0.0283                  | monitor: 0.0372
# cash machine: 0.0277            | microwave: 0.0356
# ======================================================================
# **glare44laptop** (Ground Truth: laptop)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# wing: 0.1922                    | fountain: 0.6080
# spotlight: 0.1151               | stage: 0.0539
# laptop: 0.0775*                 | spotlight: 0.0321
# fountain: 0.0716                | beer glass: 0.0267
# projector: 0.0612               | bubble: 0.0224
# ======================================================================
# **glare45electricguitar** (Ground Truth: electricguitar)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# electric guitar: 0.8887*        | electric guitar: 0.3982*
# acoustic guitar: 0.0425         | stage: 0.1564
# stage: 0.0230                   | theater curtain: 0.1467
# pick: 0.0072                    | violin: 0.0273
# violin: 0.0046                  | acoustic guitar: 0.0263
# ======================================================================
# **glare46streetsign** (Ground Truth: streetsign)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# traffic light: 0.7412           | traffic light: 0.3815
# spotlight: 0.1678               | syringe: 0.1417
# pole: 0.0128                    | projector: 0.1044
# projector: 0.0122               | spotlight: 0.0404
# stage: 0.0052                   | microphone: 0.0237
# ======================================================================
# **glare47trafficlight** (Ground Truth: trafficlight)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# traffic light: 0.4688*          | traffic light: 0.6263*
# spotlight: 0.2894               | spotlight: 0.1168
# suspension bridge: 0.0776       | stage: 0.0799
# pier: 0.0709                    | suspension bridge: 0.0144
# stage: 0.0238                   | pier: 0.0102
# ======================================================================
# **glare48light** (Ground Truth: light)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# spotlight: 0.9976*              | spotlight: 0.6878*
# lampshade: 0.0007               | fountain: 0.1622
# projector: 0.0005               | projector: 0.0242
# torch: 0.0002                   | electric fan: 0.0071
# tripod: 0.0002                  | tripod: 0.0052
# ======================================================================
# **glare49lamppost** (Ground Truth: lamppost)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# flagpole: 0.8507                | fountain: 0.8218
# pole: 0.0592                    | spider web: 0.0441
# spotlight: 0.0368               | umbrella: 0.0258
# fountain: 0.0201                | bubble: 0.0131
# solar dish: 0.0063              | solar dish: 0.0090
# ======================================================================
# **glare4Tree** (Ground Truth: Tree)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# beaker: 0.6245                  | mixing bowl: 0.1632
# beer glass: 0.1017              | beer glass: 0.1137
# car mirror: 0.0339              | mud turtle: 0.0766
# ladle: 0.0337                   | beaker: 0.0597
# Petri dish: 0.0325              | goblet: 0.0573
# ======================================================================
# **glare50seashore** (Ground Truth: seashore)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# window shade: 0.3958            | wardrobe: 0.1348
# shower curtain: 0.1263          | shower curtain: 0.0424
# mosquito net: 0.1030            | fountain: 0.0314
# lampshade: 0.0728               | spotlight: 0.0309
# spotlight: 0.0605               | swab: 0.0304
# ======================================================================
# **glare5Car** (Ground Truth: Car)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# fountain: 0.1319                | toyshop: 0.3220
# snowplow: 0.1012                | altar: 0.1446
# stage: 0.0742                   | caldron: 0.0711
# toyshop: 0.0573                 | snowplow: 0.0461
# caldron: 0.0525                 | fire screen: 0.0182
# ======================================================================
# **glare6backpack** (Ground Truth: backpack)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# scuba diver: 0.1789             | jellyfish: 0.2202
# spotlight: 0.0693               | scuba diver: 0.1070
# dugong: 0.0428                  | electric ray: 0.0499
# projector: 0.0421               | bubble: 0.0377
# stage: 0.0340                   | dugong: 0.0278
# ======================================================================
# **glare7mouse** (Ground Truth: mouse)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# mouse: 0.9997*                  | mouse: 0.9221*
# notebook: 0.0000                | bubble: 0.0333
# laptop: 0.0000                  | bullet train: 0.0025
# computer keyboard: 0.0000       | Granny Smith: 0.0021
# joystick: 0.0000                | tick: 0.0020
# ======================================================================
# **glare8keyboard** (Ground Truth: keyboard)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# computer keyboard: 0.9626*      | computer keyboard: 0.4685*
# space bar: 0.0265               | space bar: 0.1385
# typewriter keyboard: 0.0063*    | laptop: 0.1070
# mouse: 0.0016                   | hand-held computer: 0.0768
# notebook: 0.0014                | notebook: 0.0355
# ======================================================================
# **glare9cup** (Ground Truth: cup)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# pill bottle: 0.0442             | water bottle: 0.0319
# water bottle: 0.0419            | pill bottle: 0.0312
# piggy bank: 0.0366              | piggy bank: 0.0311
# electric fan: 0.0245            | toilet tissue: 0.0297
# thimble: 0.0236                 | thimble: 0.0232
# ======================================================================

# %%
print([original_correct,predicted_correct,len(processed_improved_list)])
# Out:
# [31, 23, 6]

# %%
processed_improved_list
# Out:
# [{0.95809406042099, 0.9751546382904053, 'glare18remotecontrol'},
#  {0.6868853569030762, 0.7803388833999634, 'glare19ballpoint'},
#  {0.4329182803630829, 0.45902019739151, 'glare20window'},
#  {0.9861650466918945, 0.9907941222190857, 'glare38measuringcup'},
#  {0.7205631732940674, 0.7657079100608826, 'glare40laptop'},
#  {0.4687767028808594, 0.6263253092765808, 'glare47trafficlight'}]
