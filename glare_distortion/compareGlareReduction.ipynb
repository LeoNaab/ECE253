# %%
import torch
from torchvision.models import resnet50, ResNet50_Weights
import cv2
from torchvision.transforms import transforms
from PIL import Image
import os
import re

# %%
weights = ResNet50_Weights.IMAGENET1K_V1
model = resnet50(weights=weights)

preprocess = weights.transforms()
categories = weights.meta["categories"]

def image_loader(image_name):
    if not os.path.exists(image_name):
        print(f"ERROR: File not found at path: {image_name}")
        return None
        
    image = Image.open(image_name).convert("RGB")
    return image

# %%
glare_images = 'glare_images/'
glare_reduction = 'glare_reduction_outputs/'
results = {}
labels = []

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
def getLabel(filename):
    match = re.search(r'glare\d+(.*?)\.jpg$', filename)
    if match:
        return match.group(1) # Return the content of the captured group (.*?)
    return None

# %%
def get_predictions(input_batch, image_type, file_key, verbose=False):
    with torch.no_grad():
        output = model(input_batch)
        
    probabilities = torch.nn.functional.softmax(output[0], dim=0)
    
    # Get Top 5 Predictions
    top5_prob, top5_indices = torch.topk(probabilities, 5)
    
    predictions = []
    for i in range(top5_prob.size(0)):
        predicted_index = top5_indices[i].item()
        predicted_label = categories[predicted_index]
        probability = top5_prob[i].item()
        predictions.append({
            "rank": i + 1,
            "label": predicted_label,
            "probability": probability
        })
    
    # Get the single best prediction (index 0 of the list)
    best_pred = predictions[0]
    
    results[file_key][image_type] = {
        "best_label": best_pred["label"],
        "best_probability": best_pred["probability"],
        "top_5_predictions": predictions
    }
    
    if(verbose):
        print(f"  {image_type.capitalize()} Best Label: **{best_pred['label']}** (P: {best_pred['probability']:.4f})")

# %%
verbose = False
print(f"Starting batch prediction on device: {device}")
print("-" * 50)

for filename in os.listdir(glare_images):
    if filename.endswith(".jpg") or filename.endswith(".jpeg") or filename.endswith(".png"):
        
        original_file_path = os.path.join(glare_images, filename)
        processed_filename = 'processed1_' + filename
        processed_file_path = os.path.join(glare_reduction, processed_filename) 
        
        if not os.path.exists(processed_file_path):
            print(f"Warning: Corresponding processed file not found for **{filename}**. Skipping.")
            continue
            
        if(verbose):
            print(f"Processing: **{filename}**")
        
        file_key = os.path.splitext(filename)[0]
        results[file_key] = {
            "original": {},
            "processed": {},
            "label" : getLabel(filename)
        }
        
        try:
            image_original = image_loader(original_file_path)
            image_processed = image_loader(processed_file_path)
            
            input_tensor_original = preprocess(image_original)
            input_tensor_processed = preprocess(image_processed)
            
            input_batch_original = input_tensor_original.unsqueeze(0).to(device)
            input_batch_processed = input_tensor_processed.unsqueeze(0).to(device)
            
            get_predictions(input_batch_original, "original", file_key)
            get_predictions(input_batch_processed, "processed",file_key)
            if(verbose):
                print("-" * 50)
            
        except Exception as e:
            print(f"An error occurred while processing **{filename}**: {e}")
            del results[file_key] # Remove incomplete result
            print("-" * 50)
            continue
            
print("Batch processing complete.")
# Out:
# Starting batch prediction on device: cuda
# --------------------------------------------------
# Batch processing complete.

# %%
def check_label_match(ground_truth, predicted_label):
    gt = ground_truth.lower().replace(" ", "")
    pl = predicted_label.lower().replace(" ", "")
    # print(f"ground truth: {gt} == {pl} : predicted")
    if gt in pl:
        return True
    
    if pl in gt:
        return True
        
    if gt == pl:
        return True
        
    return False

# %%
def print_side_by_side_comparison(results_dict, print_results=False):
    max_label_width = 0
    
    # Find the longest label across all Top 5 lists
    for data in results_dict.values():
        for pred in data["original"]["top_5_predictions"]:
            max_label_width = max(max_label_width, len(pred["label"]))
        for pred in data["processed"]["top_5_predictions"]:
            max_label_width = max(max_label_width, len(pred["label"]))

    label_padding = max_label_width + 12
    orig_top1 = 0
    original_correct = 0
    processed_correct = 0
    proc_top1 = 0
    processed_improved_list = []
    for file_key, data in results_dict.items():
        original_preds = data["original"]["top_5_predictions"]
        processed_preds = data["processed"]["top_5_predictions"]
        ground_truth = data['label'] 
        if(print_results):
            print("=" * 70)
            print(f"**{file_key}** (Ground Truth: {ground_truth})")
            print("-" * 70)
            
            header_format = f"{'Original Top 5':<{label_padding}} | {'Processed Top 5'}"
            print(header_format)
            print("-" * 70)

        original_is_counted = False
        processed_is_counted = False
        original_prob = 0
        processed_prob = 0

        for i in range(5):
            orig_label = original_preds[i]['label']
            orig_prob = original_preds[i]['probability']
            orig_is_match = check_label_match(ground_truth, orig_label)
            if i == 0 and orig_is_match:
                orig_top1 += 1
            orig_star = "*" if orig_is_match else ""
            if orig_is_match and not original_is_counted:
                original_correct += 1 
                original_is_counted = True
                original_prob = orig_prob
            
            proc_label = processed_preds[i]['label']
            proc_prob = processed_preds[i]['probability']
            proc_is_match = check_label_match(ground_truth, proc_label)
            if i == 0 and proc_is_match:
                proc_top1 += 1
            proc_star = "*" if proc_is_match else ""
            if proc_is_match and not processed_is_counted:
                processed_correct += 1 
                processed_is_counted = True
                processed_prob = proc_prob
            
            orig_output = f"{orig_label}: {orig_prob:.4f}{orig_star}"
            proc_output = f"{proc_label}: {proc_prob:.4f}{proc_star}"
            
            # Use f-string formatting to align the original column based on max width
            comparison_line = f"{orig_output:<{label_padding}} | {proc_output}"
            
            if(print_results):
                print(comparison_line)

        if(original_correct != 0 and processed_correct != 0 and original_prob < processed_prob): 
            processed_improved_list.append([file_key, original_prob, processed_prob])
        
    if(print_results):
        print("=" * 70)
    return original_correct, processed_correct, processed_improved_list, orig_top1, proc_top1

# %%
print_results = True
original_correct, predicted_correct, processed_improved_list, orig_top1, proc_top1 = print_side_by_side_comparison(results, print_results=print_results)
# Out:
# ======================================================================
# **glare10spotlight** (Ground Truth: spotlight)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# spotlight: 0.4768*              | spotlight: 0.5010*
# lampshade: 0.4680               | lampshade: 0.3143
# table lamp: 0.0290              | candle: 0.1068
# candle: 0.0129                  | table lamp: 0.0253
# matchstick: 0.0014              | matchstick: 0.0187
# ======================================================================
# **glare11bowl** (Ground Truth: bowl)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# spotlight: 0.5431               | bubble: 0.3946
# candle: 0.1663                  | mouse: 0.2195
# mouse: 0.0619                   | spotlight: 0.1514
# bubble: 0.0505                  | candle: 0.1124
# Petri dish: 0.0440              | Petri dish: 0.0592
# ======================================================================
# **glare12ruler** (Ground Truth: ruler)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# rule: 0.1706*                   | wall clock: 0.1770
# digital clock: 0.1405           | menu: 0.0917
# CD player: 0.1028               | sliding door: 0.0792
# microwave: 0.0990               | wardrobe: 0.0787
# screen: 0.0802                  | barometer: 0.0569
# ======================================================================
# **glare13notebook** (Ground Truth: notebook)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# monitor: 0.3529                 | screen: 0.2398
# screen: 0.3053                  | monitor: 0.2222
# television: 0.1011              | projector: 0.0541
# notebook: 0.0450*               | television: 0.0524
# projector: 0.0288               | modem: 0.0452
# ======================================================================
# **glare14remotecontroller** (Ground Truth: remotecontroller)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# remote control: 0.7515*         | remote control: 0.4827*
# cellular telephone: 0.1530      | cellular telephone: 0.1165
# CD player: 0.0144               | projector: 0.0924
# modem: 0.0136                   | CD player: 0.0469
# projector: 0.0127               | modem: 0.0465
# ======================================================================
# **glare15screwdriver** (Ground Truth: screwdriver)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# screwdriver: 0.9996*            | screwdriver: 0.9996*
# plunger: 0.0003                 | plunger: 0.0002
# syringe: 0.0001                 | syringe: 0.0001
# swab: 0.0000                    | letter opener: 0.0000
# paddle: 0.0000                  | carpenter's kit: 0.0000
# ======================================================================
# **glare16RV** (Ground Truth: RV)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# ambulance: 0.2485               | ambulance: 0.5058
# moving van: 0.1827              | moving van: 0.2340
# police van: 0.1110              | police van: 0.0750
# carton: 0.1093                  | minibus: 0.0219
# minibus: 0.0836                 | carton: 0.0217
# ======================================================================
# **glare17bandaid** (Ground Truth: bandaid)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# Band Aid: 0.9999*               | Band Aid: 0.9632*
# spatula: 0.0000                 | lighter: 0.0063
# rubber eraser: 0.0000           | seat belt: 0.0049
# seat belt: 0.0000               | rubber eraser: 0.0016
# envelope: 0.0000                | lampshade: 0.0015
# ======================================================================
# **glare18remotecontrol** (Ground Truth: remotecontrol)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# remote control: 0.9581*         | remote control: 0.9622*
# joystick: 0.0054                | joystick: 0.0083
# cellular telephone: 0.0053      | switch: 0.0037
# switch: 0.0026                  | cellular telephone: 0.0026
# radio: 0.0022                   | radio: 0.0025
# ======================================================================
# **glare19ballpoint** (Ground Truth: ballpoint)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# ballpoint: 0.6869*              | ballpoint: 0.9533*
# rubber eraser: 0.0848           | paintbrush: 0.0165
# pencil sharpener: 0.0329        | rubber eraser: 0.0062
# hammer: 0.0262                  | syringe: 0.0053
# paintbrush: 0.0187              | snorkel: 0.0034
# ======================================================================
# **glare1sunglasses** (Ground Truth: sunglasses)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# sunglasses: 0.7765*             | sunglasses: 0.6194*
# sunglass: 0.2158*               | sunglass: 0.2308*
# projector: 0.0039               | projector: 0.0980
# binoculars: 0.0012              | binoculars: 0.0079
# washer: 0.0003                  | wing: 0.0043
# ======================================================================
# **glare20window** (Ground Truth: window)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# sliding door: 0.4832            | sliding door: 0.4331
# window screen: 0.4329*          | window screen: 0.3923*
# window shade: 0.0696*           | window shade: 0.1231*
# fire screen: 0.0044             | fire screen: 0.0110
# shoji: 0.0018                   | screen: 0.0051
# ======================================================================
# **glare21ZOMG** (Ground Truth: ZOMG)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# tennis ball: 0.9146             | tennis ball: 0.3036
# volleyball: 0.0290              | mouse: 0.2156
# soccer ball: 0.0238             | CD player: 0.0882
# CD player: 0.0041               | soccer ball: 0.0828
# rugby ball: 0.0040              | piggy bank: 0.0334
# ======================================================================
# **glare22waterbottle** (Ground Truth: waterbottle)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# water bottle: 0.9011*           | water bottle: 0.9927*
# pop bottle: 0.0894              | pop bottle: 0.0038
# beer bottle: 0.0045             | water jug: 0.0022
# beer glass: 0.0009              | syringe: 0.0001
# wine bottle: 0.0006             | beer glass: 0.0001
# ======================================================================
# **glare23microwave** (Ground Truth: microwave)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# microwave: 0.5417*              | microwave: 0.4812*
# rotisserie: 0.0821              | television: 0.0913
# window screen: 0.0648           | screen: 0.0841
# toaster: 0.0536                 | window screen: 0.0602
# fire screen: 0.0363             | loudspeaker: 0.0328
# ======================================================================
# **glare24cabinet** (Ground Truth: cabinet)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# stove: 0.3099                   | stove: 0.5567
# microwave: 0.1454               | microwave: 0.1677
# safe: 0.1446                    | safe: 0.0484
# refrigerator: 0.0584            | switch: 0.0481
# switch: 0.0477                  | refrigerator: 0.0303
# ======================================================================
# **glare25rubber** (Ground Truth: rubber)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# rubber eraser: 0.8904*          | sunscreen: 0.2266
# packet: 0.0335                  | hair spray: 0.2079
# matchstick: 0.0316              | lotion: 0.1674
# book jacket: 0.0115             | book jacket: 0.0451
# street sign: 0.0059             | perfume: 0.0414
# ======================================================================
# **glare26winebottle** (Ground Truth: winebottle)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# wine bottle: 0.3121*            | beer bottle: 0.3452
# beer bottle: 0.2927             | wine bottle: 0.3437*
# whiskey jug: 0.2500             | whiskey jug: 0.1343
# pop bottle: 0.0586              | red wine: 0.0818
# red wine: 0.0521                | pop bottle: 0.0590
# ======================================================================
# **glare27coffeemug** (Ground Truth: coffeemug)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# coffee mug: 0.8901*             | coffee mug: 0.7500*
# cup: 0.0835                     | cup: 0.0942
# espresso: 0.0068                | beer glass: 0.0510
# beer glass: 0.0061              | candle: 0.0219
# coffeepot: 0.0030               | water bottle: 0.0097
# ======================================================================
# **glare28mixingbowl** (Ground Truth: mixingbowl)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# mixing bowl: 0.4658*            | mixing bowl: 0.5058*
# ladle: 0.0403                   | ladle: 0.0992
# measuring cup: 0.0364           | soup bowl: 0.0327
# Petri dish: 0.0339              | strainer: 0.0262
# tray: 0.0333                    | tray: 0.0260
# ======================================================================
# **glare29toaster** (Ground Truth: toaster)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# toaster: 0.7179*                | toaster: 0.6354*
# car mirror: 0.0577              | vacuum: 0.0284
# minivan: 0.0136                 | car mirror: 0.0256
# coffeepot: 0.0134               | projector: 0.0215
# revolver: 0.0113                | coffeepot: 0.0200
# ======================================================================
# **glare2backpack** (Ground Truth: backpack)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# balloon: 0.1660                 | scuba diver: 0.1509
# parachute: 0.1308               | spotlight: 0.1045
# spotlight: 0.0830               | caldron: 0.0416
# bobsled: 0.0468                 | dugong: 0.0395
# bubble: 0.0467                  | electric ray: 0.0392
# ======================================================================
# **glare2Car** (Ground Truth: Car)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# fire engine: 0.0890             | traffic light: 0.1528
# spotlight: 0.0760               | fire engine: 0.0930
# volcano: 0.0561                 | spotlight: 0.0545
# snowplow: 0.0493                | snowplow: 0.0446
# fountain: 0.0349                | volcano: 0.0390
# ======================================================================
# **glare30watertank** (Ground Truth: watertank)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# beer glass: 0.1181              | spotlight: 0.0971
# spotlight: 0.0967               | beer glass: 0.0743
# goblet: 0.0703                  | bucket: 0.0598
# bucket: 0.0650                  | water jug: 0.0542
# water jug: 0.0497               | goblet: 0.0398
# ======================================================================
# **glare31television** (Ground Truth: television)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# grand piano: 0.1995             | grand piano: 0.5045
# washbasin: 0.1242               | projector: 0.0671
# home theater: 0.0717            | spotlight: 0.0438
# projector: 0.0516               | washbasin: 0.0392
# loudspeaker: 0.0410             | home theater: 0.0339
# ======================================================================
# **glare32refrigerator** (Ground Truth: refrigerator)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# sliding door: 0.1869            | refrigerator: 0.5233*
# window shade: 0.1273            | dishwasher: 0.4203
# bannister: 0.0595               | sliding door: 0.0124
# dishwasher: 0.0532              | washer: 0.0086
# spotlight: 0.0313               | microwave: 0.0079
# ======================================================================
# **glare33sandal** (Ground Truth: sandal)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# Band Aid: 0.6448                | Band Aid: 0.8508
# punching bag: 0.0622            | pill bottle: 0.0401
# water bottle: 0.0340            | nipple: 0.0302
# nipple: 0.0284                  | punching bag: 0.0117
# pill bottle: 0.0282             | water jug: 0.0110
# ======================================================================
# **glare34broom** (Ground Truth: broom)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# broom: 0.9994*                  | broom: 0.9967*
# swab: 0.0002                    | paintbrush: 0.0011
# paintbrush: 0.0001              | plunger: 0.0008
# shovel: 0.0001                  | spatula: 0.0004
# plunger: 0.0001                 | shovel: 0.0003
# ======================================================================
# **glare35washer** (Ground Truth: washer)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# washer: 0.8998*                 | washer: 0.8203*
# microwave: 0.0490               | microwave: 0.0979
# scale: 0.0224                   | CD player: 0.0148
# CD player: 0.0095               | scale: 0.0114
# photocopier: 0.0069             | tape player: 0.0113
# ======================================================================
# **glare36strainer** (Ground Truth: strainer)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# strainer: 0.9993*               | strainer: 0.9986*
# saltshaker: 0.0005              | saltshaker: 0.0011
# ladle: 0.0001                   | ladle: 0.0001
# cocktail shaker: 0.0001         | cocktail shaker: 0.0001
# coffeepot: 0.0000               | coffeepot: 0.0000
# ======================================================================
# **glare37bakingpan** (Ground Truth: bakingpan)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# projector: 0.5669               | projector: 0.7275
# spotlight: 0.0911               | stove: 0.0563
# stove: 0.0373                   | spotlight: 0.0442
# laptop: 0.0297                  | laptop: 0.0214
# rotisserie: 0.0189              | CD player: 0.0129
# ======================================================================
# **glare38measuringcup** (Ground Truth: measuringcup)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# measuring cup: 0.9862*          | measuring cup: 0.9712*
# cocktail shaker: 0.0092         | cocktail shaker: 0.0182
# cup: 0.0012*                    | beer glass: 0.0037
# beer glass: 0.0010              | cup: 0.0018*
# water jug: 0.0004               | water jug: 0.0007
# ======================================================================
# **glare39canopener** (Ground Truth: canopener)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# fountain pen: 0.1581            | projector: 0.3574
# ballpoint: 0.1188               | spotlight: 0.0796
# hair slide: 0.0911              | lighter: 0.0634
# scabbard: 0.0880                | pay-phone: 0.0593
# projector: 0.0564               | loudspeaker: 0.0576
# ======================================================================
# **glare3lampshade** (Ground Truth: lampshade)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# lampshade: 0.2596*              | lampshade: 0.5252*
# goblet: 0.1696                  | radio telescope: 0.0939
# radio telescope: 0.0980         | airship: 0.0418
# cup: 0.0654                     | table lamp: 0.0374
# table lamp: 0.0490              | drum: 0.0270
# ======================================================================
# **glare40laptop** (Ground Truth: laptop)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# laptop: 0.7206*                 | laptop: 0.7426*
# notebook: 0.2509                | notebook: 0.2261
# computer keyboard: 0.0128       | computer keyboard: 0.0137
# monitor: 0.0029                 | monitor: 0.0035
# space bar: 0.0028               | space bar: 0.0028
# ======================================================================
# **glare41switch** (Ground Truth: switch)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# switch: 0.9995*                 | switch: 0.9966*
# safe: 0.0001                    | spotlight: 0.0005
# medicine chest: 0.0000          | safe: 0.0003
# wall clock: 0.0000              | medicine chest: 0.0002
# spotlight: 0.0000               | joystick: 0.0001
# ======================================================================
# **glare42umbrella** (Ground Truth: umbrella)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# umbrella: 0.9968*               | umbrella: 0.8247*
# plastic bag: 0.0017             | plastic bag: 0.0632
# mountain tent: 0.0006           | projector: 0.0221
# mosquito net: 0.0002            | mountain tent: 0.0117
# lampshade: 0.0001               | spotlight: 0.0066
# ======================================================================
# **glare43welcomemat** (Ground Truth: welcomemat)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# screen: 0.3417                  | screen: 0.3772
# monitor: 0.2341                 | monitor: 0.2589
# modem: 0.0385                   | oscilloscope: 0.0287
# laptop: 0.0283                  | projector: 0.0259
# cash machine: 0.0277            | laptop: 0.0217
# ======================================================================
# **glare44laptop** (Ground Truth: laptop)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# wing: 0.1922                    | projector: 0.1527
# spotlight: 0.1151               | spotlight: 0.1114
# laptop: 0.0775*                 | screen: 0.0900
# fountain: 0.0716                | wing: 0.0800
# projector: 0.0612               | stage: 0.0642
# ======================================================================
# **glare45electricguitar** (Ground Truth: electricguitar)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# electric guitar: 0.8887*        | electric guitar: 0.8286*
# acoustic guitar: 0.0425         | stage: 0.0467
# stage: 0.0230                   | acoustic guitar: 0.0302
# pick: 0.0072                    | theater curtain: 0.0162
# violin: 0.0046                  | violin: 0.0158
# ======================================================================
# **glare46streetsign** (Ground Truth: streetsign)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# traffic light: 0.7412           | traffic light: 0.7027
# spotlight: 0.1678               | spotlight: 0.0754
# pole: 0.0128                    | projector: 0.0209
# projector: 0.0122               | trailer truck: 0.0183
# stage: 0.0052                   | desktop computer: 0.0161
# ======================================================================
# **glare47trafficlight** (Ground Truth: trafficlight)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# traffic light: 0.4688*          | traffic light: 0.4173*
# spotlight: 0.2894               | spotlight: 0.3923
# suspension bridge: 0.0776       | suspension bridge: 0.0667
# pier: 0.0709                    | pier: 0.0397
# stage: 0.0238                   | stage: 0.0178
# ======================================================================
# **glare48light** (Ground Truth: light)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# spotlight: 0.9976*              | spotlight: 0.9978*
# lampshade: 0.0007               | lampshade: 0.0008
# projector: 0.0005               | torch: 0.0003
# torch: 0.0002                   | table lamp: 0.0002
# tripod: 0.0002                  | traffic light: 0.0002*
# ======================================================================
# **glare49lamppost** (Ground Truth: lamppost)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# flagpole: 0.8507                | flagpole: 0.4862
# pole: 0.0592                    | spotlight: 0.2093
# spotlight: 0.0368               | pole: 0.1456
# fountain: 0.0201                | fountain: 0.0312
# solar dish: 0.0063              | spider web: 0.0141
# ======================================================================
# **glare4Tree** (Ground Truth: Tree)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# beaker: 0.6245                  | beaker: 0.3874
# beer glass: 0.1017              | beer glass: 0.2740
# car mirror: 0.0339              | red wine: 0.1407
# ladle: 0.0337                   | goblet: 0.0410
# Petri dish: 0.0325              | water bottle: 0.0169
# ======================================================================
# **glare50seashore** (Ground Truth: seashore)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# window shade: 0.3958            | seashore: 0.5589*
# shower curtain: 0.1263          | beacon: 0.1313
# mosquito net: 0.1030            | promontory: 0.1292
# lampshade: 0.0728               | lakeside: 0.0447
# spotlight: 0.0605               | drilling platform: 0.0203
# ======================================================================
# **glare51streetsign** (Ground Truth: streetsign)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# traffic light: 0.5051           | traffic light: 0.7780
# street sign: 0.3877*            | street sign: 0.1065*
# crane: 0.0288                   | crane: 0.0192
# pole: 0.0111                    | solar dish: 0.0142
# solar dish: 0.0067              | pole: 0.0108
# ======================================================================
# **glare52couch** (Ground Truth: couch)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# cowboy boot: 0.2126             | sleeping bag: 0.2841
# sleeping bag: 0.1870            | studio couch: 0.1676*
# home theater: 0.1218            | home theater: 0.1022
# studio couch: 0.1128*           | seat belt: 0.0756
# pillow: 0.0523                  | pillow: 0.0517
# ======================================================================
# **glare53menu** (Ground Truth: menu)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# screwdriver: 0.4212             | menu: 0.9808*
# carpenter's kit: 0.0821         | pay-phone: 0.0027
# radio: 0.0436                   | turnstile: 0.0024
# odometer: 0.0396                | radio: 0.0018
# scoreboard: 0.0367              | brass: 0.0018
# ======================================================================
# **glare54balloon** (Ground Truth: balloon)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# balloon: 0.7790*                | balloon: 0.8335*
# abacus: 0.0282                  | soap dispenser: 0.0080
# maraca: 0.0179                  | abacus: 0.0066
# confectionery: 0.0157           | toyshop: 0.0051
# vending machine: 0.0156         | confectionery: 0.0050
# ======================================================================
# **glare55bee** (Ground Truth: bee)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# knot: 0.5346                    | mortarboard: 0.5672
# mortarboard: 0.3589             | academic gown: 0.0514
# academic gown: 0.0210           | trench coat: 0.0304
# flagpole: 0.0165                | Band Aid: 0.0169
# sarong: 0.0120                  | vestment: 0.0164
# ======================================================================
# **glare56mountaintent** (Ground Truth: mountaintent)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# mountain tent: 0.9302*          | mountain tent: 0.9269*
# lampshade: 0.0354               | lampshade: 0.0421
# umbrella: 0.0114                | mosquito net: 0.0113
# mosquito net: 0.0105            | umbrella: 0.0093
# table lamp: 0.0029              | table lamp: 0.0034
# ======================================================================
# **glare57pooltable** (Ground Truth: pooltable)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# pool table: 0.9998*             | pool table: 0.9997*
# cowboy hat: 0.0000              | cowboy hat: 0.0001
# ping-pong ball: 0.0000          | ping-pong ball: 0.0000
# pickup: 0.0000                  | sombrero: 0.0000
# chest: 0.0000                   | violin: 0.0000
# ======================================================================
# **glare58soupbowl** (Ground Truth: soupbowl)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# wok: 0.5395                     | hot pot: 0.5039
# hot pot: 0.2549                 | wok: 0.2674
# soup bowl: 0.0825*              | soup bowl: 0.0985*
# frying pan: 0.0825              | Crock Pot: 0.0403
# Dutch oven: 0.0086              | frying pan: 0.0179
# ======================================================================
# **glare59desktopcomputer** (Ground Truth: desktopcomputer)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# oscilloscope: 0.3747            | oscilloscope: 0.4028
# projector: 0.1822               | projector: 0.2553
# desktop computer: 0.1457*       | desktop computer: 0.1323*
# modem: 0.1042                   | monitor: 0.0624
# hard disc: 0.0612               | modem: 0.0377
# ======================================================================
# **glare5Car** (Ground Truth: Car)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# fountain: 0.1319                | cab: 0.3482
# snowplow: 0.1012                | snowplow: 0.1161
# stage: 0.0742                   | limousine: 0.0631
# toyshop: 0.0573                 | fountain: 0.0486
# caldron: 0.0525                 | stage: 0.0465
# ======================================================================
# **glare60barbell** (Ground Truth: barbell)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# odometer: 0.8789                | odometer: 0.2740
# projector: 0.0151               | electric fan: 0.2488
# disk brake: 0.0136              | barbell: 0.2447*
# analog clock: 0.0123            | scale: 0.1108
# electric fan: 0.0105            | projector: 0.0300
# ======================================================================
# **glare6backpack** (Ground Truth: backpack)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# scuba diver: 0.1789             | scuba diver: 0.1628
# spotlight: 0.0693               | spotlight: 0.0713
# dugong: 0.0428                  | rain barrel: 0.0492
# projector: 0.0421               | dugong: 0.0480
# stage: 0.0340                   | electric ray: 0.0448
# ======================================================================
# **glare7mouse** (Ground Truth: mouse)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# mouse: 0.9997*                  | mouse: 0.9983*
# notebook: 0.0000                | laptop: 0.0004
# laptop: 0.0000                  | notebook: 0.0003
# computer keyboard: 0.0000       | desktop computer: 0.0001
# joystick: 0.0000                | joystick: 0.0001
# ======================================================================
# **glare8keyboard** (Ground Truth: keyboard)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# computer keyboard: 0.9626*      | computer keyboard: 0.9385*
# space bar: 0.0265               | space bar: 0.0479
# typewriter keyboard: 0.0063*    | typewriter keyboard: 0.0084*
# mouse: 0.0016                   | notebook: 0.0019
# notebook: 0.0014                | mouse: 0.0014
# ======================================================================
# **glare9cup** (Ground Truth: cup)
# ----------------------------------------------------------------------
# Original Top 5                  | Processed Top 5
# ----------------------------------------------------------------------
# pill bottle: 0.0442             | water bottle: 0.0482
# water bottle: 0.0419            | electric fan: 0.0239
# piggy bank: 0.0366              | shower curtain: 0.0238
# electric fan: 0.0245            | piggy bank: 0.0229
# thimble: 0.0236                 | water jug: 0.0202
# ======================================================================

# %%
print([original_correct,predicted_correct,len(processed_improved_list)])
# Out:
# [38, 38, 17]

# %%
processed_improved_list
# Out:
# [['glare10spotlight', 0.4767727255821228, 0.5010380148887634],
#  ['glare15screwdriver', 0.9995918869972229, 0.9996447563171387],
#  ['glare18remotecontrol', 0.95809406042099, 0.9622239470481873],
#  ['glare19ballpoint', 0.6868853569030762, 0.953280508518219],
#  ['glare22waterbottle', 0.9011024832725525, 0.9927190542221069],
#  ['glare26winebottle', 0.31214749813079834, 0.3436669111251831],
#  ['glare28mixingbowl', 0.4658496081829071, 0.5057600736618042],
#  ['glare32refrigerator', 0, 0.5233057141304016],
#  ['glare3lampshade', 0.25956276059150696, 0.525222659111023],
#  ['glare40laptop', 0.7205631732940674, 0.742561399936676],
#  ['glare48light', 0.9976363182067871, 0.9977924823760986],
#  ['glare50seashore', 0, 0.5589098334312439],
#  ['glare52couch', 0.11283918470144272, 0.1676052212715149],
#  ['glare53menu', 0, 0.9807819128036499],
#  ['glare54balloon', 0.7789914011955261, 0.8334944248199463],
#  ['glare58soupbowl', 0.08248457312583923, 0.09845738112926483],
#  ['glare60barbell', 0, 0.2447320818901062]]

# %%
print(f'OG Acc: {original_correct/(len(os.listdir(glare_images)))}')
print(f'Processed Acc: {predicted_correct/(len(os.listdir(glare_images)))}')
# Out:
# OG Acc: 0.6229508196721312
# Processed Acc: 0.6229508196721312

# %%
print(f'OG Acc Best Guess: {orig_top1/(len(os.listdir(glare_images)))}')
print(f'Processed Acc Best Guess: {proc_top1/(len(os.listdir(glare_images)))}')
# Out:
# OG Acc Best Guess: 0.5081967213114754
# Processed Acc Best Guess: 0.5081967213114754

# %%
def calculate_metrics(data, threshold=0.5):
    total_improvement = 0.0
    threshold_crossings = 0
    N = len(data)

    for entry in data:
        P_orig = entry[1]
        P_proc = entry[2]

        improvement = P_proc - P_orig
        total_improvement += improvement

        # Check for Threshold Crossing: Original was uncertain (< 0.5) 
        # and Processed became certain (>= 0.5)
        if P_orig < threshold and P_proc >= threshold:
            threshold_crossings += 1

    MAI = total_improvement / N
    
    return MAI, threshold_crossings, total_improvement

# %%
MAI, crossings, total_improvement = calculate_metrics(processed_improved_list)
print(f"Mean Absolute Improvement (MAI): {MAI:.4f}")
print(f"Count of Threshold Crossings (>= 0.5): {crossings}")
# Out:
# Mean Absolute Improvement (MAI): 0.1870
# Count of Threshold Crossings (>= 0.5): 6
